# %% [markdown]
# <div align="center">
#     <font color="0F5298" size="7">
#         Deep Learning <br>
#     </font>
#     <font color="2565AE" size="5">
#         CE Department <br>
#         Spring 2024 - Prof. Soleymani Baghshah <br>
#     </font>
#     <font color="3C99D" size="5">
#         HW2 Practical <br>
#     </font>
#     <font color="696880" size="5">
#         40 Points
#     </font>
# </div>

# %% [markdown]
# You'll be building your own U-Net, a type of CNN designed for quick, precise image segmentation, and using it to predict a label for every single pixel in an image - in this case, an image from a self-driving car dataset.
#
# This type of image classification is called semantic image segmentation. It's similar to object detection in that both ask the question: "What objects are in this image and where in the image are those objects located?," but where object detection labels objects with bounding boxes that may include pixels that aren't part of the object, semantic image segmentation allows you to predict a precise mask for each object in the image by labeling each pixel in the image with its corresponding class. The word “semantic” here refers to what's being shown, so for example the “Car” class is indicated below by the dark blue mask, and "Person" is indicated with a red mask:
#
#
# ![carseg.png](data:image/png;base64,...) <br>
# <u><b>Figure 1</u></b>: Example of a segmented image <br>
#
# As you might imagine, region-specific labeling is a pretty crucial consideration for self-driving cars, which require a pixel-perfect understanding of their environment so they can change lanes and avoid other cars, or any number of traffic obstacles that can put peoples' lives in danger.
#
# By the time you finish this notebook, you'll be able to:
#
# * Build your own U-Net
# * Explain the difference between a regular CNN and a U-net
# * Implement semantic image segmentation on the CARLA self-driving car dataset
# * Apply sparse categorical crossentropy for pixelwise prediction
#
# Onward, to this grand and glorious quest!

# %% [markdown]
# ## Downloading Dataset

# %%
# !pip install --upgrade --no-cache-dir gdown
# !pip install torch-summary
# !gdown --id 11r4jZIlLMaX8b36lESUpPRiQi_GIcOA3
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.11/dist-packages (5.2.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from gdown) (4.13.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from gdown) (3.18.0)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.11/dist-packages (from gdown) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from gdown) (4.67.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->gdown) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->gdown) (4.14.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (2025.6.15)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (1.7.1)
# Collecting torch-summary
#   Downloading torch_summary-1.4.5-py3-none-any.whl.metadata (18 kB)
# Downloading torch_summary-1.4.5-py3-none-any.whl (16 kB)
# Installing collected packages: torch-summary
# Successfully installed torch-summary-1.4.5
# /usr/local/lib/python3.11/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=11r4jZIlLMaX8b36lESUpPRiQi_GIcOA3
# From (redirected): https://drive.google.com/uc?id=11r4jZIlLMaX8b36lESUpPRiQi_GIcOA3&confirm=t&uuid=0163e118-1818-4aca-a2a4-f3ae69b7d977
# To: /kaggle/working/Files.zip
# 100%|████████████████████████████████████████| 545M/545M [00:06<00:00, 83.5MB/s]

# %%
# !unzip Files.zip ;

# %% [markdown]
# <a name='1'></a>
# ## 1 - Packages
#
# Run the cell below to import all the libraries you'll need:

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F

from torchsummary import summary
from torchvision import transforms, io
from torch.utils.data import Dataset, DataLoader
from PIL import Image
import os
import pandas as pd
import imageio
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Chack if GPU is available

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
ls /kaggle/working/Files/data
# Out:
# CameraMask/  CameraRGB/

# %% [markdown]
# <a name='2'></a>
# ## 2 - Load the Data

# %%
path = '/kaggle/working/Files/'
image_path = os.path.join(path, 'data/CameraRGB/')
mask_path = os.path.join(path, 'data/CameraMask/')
image_list = os.listdir(image_path)
mask_list = os.listdir(mask_path)
image_list = [image_path+i for i in image_list]
mask_list = [mask_path+i for i in mask_list]

# %% [markdown]
# ### Check out the some of the unmasked and masked images from the dataset:
#
# After you are done exploring, revert back to `N=2`. Otherwise the autograder will throw a `list index out of range` error.

# %%
N = 2
img = imageio.imread(image_list[N])
mask = imageio.imread(mask_list[N])

fig, arr = plt.subplots(1, 2, figsize=(14, 10))
arr[0].imshow(img)
arr[0].set_title('Image')
arr[1].imshow(mask[:, :, 0])
arr[1].set_title('Segmentation')
plt.show()
# Out:
# /tmp/ipykernel_36/385303178.py:2: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   img = imageio.imread(image_list[N])
# /tmp/ipykernel_36/385303178.py:3: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   mask = imageio.imread(mask_list[N])

# %% [markdown]
# <a name='2-2'></a>
# ### 2.2 - Preprocess Your Data

# %%
class Segmentation_Dataset(Dataset):
    def __init__(self, ImagesDirectory, MasksDirectory):
        self.ImagesDirectory = ImagesDirectory
        self.MasksDirectory = MasksDirectory
        self.images = os.listdir(self.ImagesDirectory)
        self.masks = os.listdir(self.MasksDirectory)
        self.mask_transforms = transforms.Compose([
            transforms.Resize((192, 256), interpolation=transforms.InterpolationMode.NEAREST)
        ])
        self.image_transforms = transforms.Compose([
            transforms.ToPILImage(),
            transforms.Resize((192, 256), interpolation=transforms.InterpolationMode.NEAREST),
            transforms.ToTensor(),
            transforms.Lambda(lambda x: x[0:3])
        ])

    def __len__(self):
        return len(self.images)

    def __getitem__(self, index):
        img_name = self.images[index]

        img_path = os.path.join(self.ImagesDirectory, img_name)
        img = io.read_file(img_path)
        img = io.decode_png(img)

        mask_path = os.path.join(self.MasksDirectory, img_name)
        mask = io.read_image(mask_path)
        mask, _ = torch.max(mask[0:3], dim=0, keepdim=True)
        img, mask = self.image_transforms(img), self.mask_transforms(mask)
        return {"IMAGE": img , "MASK": mask}

# %% [markdown]
# <a name='2-3'></a>
# ### 2.3 - Hyper-parameters and Optimizer

# %%
EPOCHS = 20
BATCH_SIZE =64

LR = 0.001
B1 = 0.9
B2 = 0.999

# %% [markdown]
# <a name='3'></a>
# ## 3 - U-Net
#
# U-Net, named for its U-shape, was originally created in 2015 for tumor detection, but in the years since has become a very popular choice for other semantic segmentation tasks.
#
# U-Net builds on a previous architecture called the Fully Convolutional Network, or FCN, which replaces the dense layers found in a typical CNN with a transposed convolution layer that upsamples the feature map back to the size of the original input image, while preserving the spatial information. This is necessary because the dense layers destroy spatial information (the "where" of the image), which is an essential part of image segmentation tasks. An added bonus of using transpose convolutions is that the input size no longer needs to be fixed, as it does when dense layers are used.
#
# Unfortunately, the final feature layer of the FCN suffers from information loss due to downsampling too much. It then becomes difficult to upsample after so much information has been lost, causing an output that looks rough.
#
# U-Net improves on the FCN, using a somewhat similar design, but differing in some important ways.  Instead of one transposed convolution at the end of the network, it uses a matching number of convolutions for downsampling the input image to a feature map, and transposed convolutions for upsampling those maps back up to the original input image size. It also adds skip connections, to retain information that would otherwise become lost during encoding. Skip connections send information to every upsampling layer in the decoder from the corresponding downsampling layer in the encoder, capturing finer information while also keeping computation low. These help prevent information loss, as well as model overfitting.

# %% [markdown]
# <a name='3-1'></a>
# ### 3.1 - Model Details
#
# ![unet.png](data:image/png;base64,...)<br>
# <u><b> Figure 2 </u></b>: U-Net Architecture<br>
#
# **Contracting path** (Encoder containing downsampling steps):
#
# Images are first fed through several convolutional layers which reduce height and width, while growing the number of channels.
#
# The contracting path follows a regular CNN architecture, with convolutional layers, their activations, and pooling layers to downsample the image and extract its features. In detail, it consists of the repeated application of two 3 x 3 valid padding convolutions, each followed by a rectified linear unit (ReLU) and a 2 x 2 max pooling operation with stride 2 for downsampling. At each downsampling step, the number of feature channels is doubled.
#
# **Crop function**: This step crops the image from the contracting path and concatenates it to the current image on the expanding path to create a skip connection.
#
# **Expanding path** (Decoder containing upsampling steps):
#
# The expanding path performs the opposite operation of the contracting path, growing the image back to its original size, while shrinking the channels gradually.
#
# In detail, each step in the expanding path upsamples the feature map, followed by a 2 x 2 convolution (the transposed convolution). This transposed convolution halves the number of feature channels, while growing the height and width of the image.
#
# Next is a concatenation with the correspondingly cropped feature map from the contracting path, and two 3 x 3 convolutions, each followed by a ReLU. You need to perform cropping to handle the loss of border pixels in every convolution.
#
# **Final Feature Mapping Block**: In the final layer, a 1x1 convolution is used to map each 64-component feature vector to the desired number of classes. The channel dimensions from the previous layer correspond to the number of filters used, so when you use 1x1 convolutions, you can transform that dimension by choosing an appropriate number of 1x1 filters. When this idea is applied to the last layer, you can reduce the channel dimensions to have one layer per class.
#
# The U-Net network has 23 convolutional layers in total.
#
# #### Important Note:
# The figures shown in the assignment for the U-Net architecture depict the layer dimensions and filter sizes as per the original paper on U-Net with smaller images. However, due to computational constraints for this assignment, you will code only half of those filters. The purpose of showing you the original dimensions is to give you the flavour of the original U-Net architecture. The important takeaway is that you multiply by 2 the number of filters used in the previous step. The notebook includes all of the necessary instructions and hints to help you code the U-Net architecture needed for this assignment.

# %% [markdown]
# <a name='3-2'></a>
# ### 3.2 - Convolution Blocks
# In both the encoder and the decoder, we see repeated applications of 2D convolution blocks, each followed by ReLU activation. In the following cell, you'll implement these building blocks.

# %%
import torch.nn as nn

class Block(nn.Module):

    def __init__(self, in_ch, out_ch):
        """
        Initializes the Block with the specified input and output channels.

        Args:
            in_ch (int): Number of input channels.
            out_ch (int): Number of output channels.
        """
        super().__init__()

        layers = [
            nn.Conv2d(in_ch, out_ch, kernel_size=3, padding='same'),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_ch, out_ch, kernel_size=3, padding='same'),
            nn.ReLU(inplace=True)
        ]

        self.conv = nn.Sequential(*layers)

    def forward(self, x):
        """
        Forward pass through the convolutional block.

        Args:
            x (torch.Tensor): Input tensor of shape (N, in_ch, H, W), where N is the batch size,
                              H is the height, and W is the width.

        Returns:
            torch.Tensor: Output tensor of shape (N, out_ch, H, W).
        """
        return self.conv(x)

# %%
# test your implementation
enc_block = Block(1, 64)
x         = torch.randn(1, 1, 128, 128)
enc_block(x).shape
# Out:
# torch.Size([1, 64, 128, 128])

# %% [markdown]
# <a name='3-2'></a>
# ### 3.3- Encoder (Downsampling Block)
#
# ![encoder.png](data:image/png;base64,...)<br>
# <u><b>Figure 3</u></b>: The U-Net Encoder up close <br>
#
# <a name='3-2'></a>
# ### 3.3 - Encoder (Downsampling Block)
#
# So far we have implemented the convolution operations but not the downsampling part. The contractive path consists of the repeated application of two 3x3 convolutions, each followed by a rectified linear unit (ReLU) and a 2x2 max pooling operation with stride 2 for downsampling. At each downsampling step we double the number of feature channels.
#
# We now need to add max pooling after each block to compose a list of downsampling blocks. Note that, we need to store the output of convolutional blocks before the application of max pooling. The output of convolutional blocks will be later used in the expansive path.

# %%
import torch
import torch.nn as nn


# Define the Encoder class
class Encoder(nn.Module):

    def __init__(self, chs=(3, 64, 128, 256, 512, 1024)):
        """
        Initializes the Encoder with the specified channel sizes.

        Args:
            chs (tuple): A tuple containing the number of channels for each
                         layer in the encoder.
        """
        super().__init__()

        self.enc_blocks = nn.ModuleList([
            Block(chs[i], chs[i+1]) for i in range(len(chs)-1)
        ])
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)

    def forward(self, x):
        """
        Forward pass through the encoder.

        Args:
            x (torch.Tensor): Input tensor of shape (N, C, H, W), where N is
                              the batch size, C is the number of input channels,
                              H is the height, and W is the width.

        Returns:
            list: A list of feature maps from each downsampling block.
        """
        ftrs = []

        for block in self.enc_blocks:
            x = block(x)
            ftrs.append(x)
            x = self.pool(x)

        return ftrs

# %%
# test your implementation
encoder = Encoder()
# input image
x    = torch.randn(1, 3, 128, 128)
ftrs = encoder(x)
for ftr in ftrs: print(ftr.shape)
# Out:
# torch.Size([1, 64, 128, 128])
# torch.Size([1, 128, 64, 64])
# torch.Size([1, 256, 32, 32])
# torch.Size([1, 512, 16, 16])
# torch.Size([1, 1024, 8, 8])

# %% [markdown]
# <a name='3-3'></a>
# ### 3.4 - Decoder (Upsampling Block)
#
# The decoder, or upsampling block, upsamples the features back to the original image size. At each upsampling level, you'll take the output of the corresponding encoder block and concatenate it before feeding to the next decoder block.
#
# ![decoder.png](data:image/png;base64,...)<br>
# <u><b>Figure 4</u></b>: The U-Net Decoder up close <br>
#
# The Decoder, is the expansive path of the U-Net Architecture.
#
# Every step in the expansive path consists of an upsampling of the feature map followed by a 2x2 convolution (“up-convolution”) that halves the number of feature channels, a concatenation with the feature map from the contracting path, and two 3x3 convolutions, each followed by a ReLU.
#
# Note that we have already implemented the part where two 3x3 convolutions occur followed by ReLU activation in Block. All we need to do to implement the Decoder is to add the “up-convolution” and the feature concatenation.
#
# Note that in PyTorch, the ConvTranspose2d operation performs the “up-convolution”. It accepts parameters like in_channels, out_channels, kernel_size and stride amongst others.

# %%
# Decoder class
class Decoder(nn.Module):

    def __init__(self, chs=(1024, 512, 256, 128, 64)):
        """
        Initializes the Decoder with the specified channel sizes.

        Args:
            chs (tuple): A tuple containing the number of channels for each
                         layer in the decoder.
        """
        super().__init__()
        self.chs = chs

        # Transposed convolutions for upsampling
        self.upconvs = nn.ModuleList([
            nn.ConvTranspose2d(chs[i], chs[i+1], kernel_size=4, stride=2, padding=1)
            for i in range(len(chs) - 1)
        ])

        # Decoder blocks
        self.dec_blocks = nn.ModuleList([
            Block(chs[i], chs[i+1]) for i in range(len(chs) - 1)
        ])

    def forward(self, x, enc_ftrs):
        """
        Forward pass through the decoder.

        Args:
            x (torch.Tensor): Input tensor of shape (N, C, H, W)
            enc_ftrs (list): Feature maps from the encoder for skip connections.

        Returns:
            torch.Tensor: Decoded tensor
        """
        for i in range(len(self.chs) - 1):
            x = self.upconvs[i](x)                        # Upsample
            enc_feat = enc_ftrs[i]                # Get corresponding encoder feature
            x = torch.cat([x, enc_feat], dim=1)          # Concatenate along channel dimension
            x = self.dec_blocks[i](x)                    # Apply decoding block

        return x

# %%
# test your implementation
decoder = Decoder()
decoder(ftrs[::-1][0], ftrs[::-1][1:]).shape
# Out:
# torch.Size([1, 64, 128, 128])

# %% [markdown]
# <a name='3-4'></a>
# ### 3.4 - Build the Model
#
# This is where you'll put it all together, by chaining the encoder, bottleneck, and decoder! You'll need to specify the number of output channels, which for this particular set would be 23. That's because there are 23 possible labels for each pixel in this self-driving car dataset.

# %%
import torch
import torch.nn as nn

class UNet(nn.Module):

    def __init__(self, enc_chs=(3, 64, 128, 256, 512, 1024),
                 dec_chs=(1024, 512, 256, 128, 64),
                 num_class=2):
        """
        U-Net implementation.
        """
        super().__init__()
        self.encoder = Encoder(enc_chs)
        self.decoder = Decoder(dec_chs)
        self.head = nn.Conv2d(dec_chs[-1], num_class, kernel_size=1)

    def forward(self, x):
        # Encoder -> returns list of feature maps
        enc_features = self.encoder(x)

        # Bottleneck feature = last one
        bottleneck = enc_features[-1]

        # Skip connections = all except bottleneck, reversed (deepest first)
        skips = enc_features[:-1][::-1]

        # Pass to decoder
        dec_out = self.decoder(bottleneck, skips)

        # Final conv to segmentation classes
        out = self.head(dec_out)
        return out

# %% [markdown]
# ### Check out the model summary below!

# %%
unet = UNet(enc_chs=(3, 32, 64,128,256,512), dec_chs=(512, 256, 128, 64, 32), num_class=23).to(device)
summary(unet, (3, 192, 256))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ├─Encoder: 1-1                           [-1, 32, 192, 256]        --
# |    └─ModuleList: 2                     []                        --
# |    |    └─Block: 3-1                   [-1, 32, 192, 256]        10,144
# |    └─MaxPool2d: 2-1                    [-1, 32, 96, 128]         --
# |    └─ModuleList: 2                     []                        --
# |    |    └─Block: 3-2                   [-1, 64, 96, 128]         55,424
# |    └─MaxPool2d: 2-2                    [-1, 64, 48, 64]          --
# |    └─ModuleList: 2                     []                        --
# |    |    └─Block: 3-3                   [-1, 128, 48, 64]         221,440
# |    └─MaxPool2d: 2-3                    [-1, 128, 24, 32]         --
# |    └─ModuleList: 2                     []                        --
# |    |    └─Block: 3-4                   [-1, 256, 24, 32]         885,248
# |    └─MaxPool2d: 2-4                    [-1, 256, 12, 16]         --
# |    └─ModuleList: 2                     []                        --
# |    |    └─Block: 3-5                   [-1, 512, 12, 16]         3,539,968
# |    └─MaxPool2d: 2-5                    [-1, 512, 6, 8]           --
# ├─Decoder: 1-2                           [-1, 32, 192, 256]        --
# |    └─ModuleList: 2                     []                        --
# |    |    └─ConvTranspose2d: 3-6         [-1, 256, 24, 32]         2,097,408
# |    └─ModuleList: 2                     []                        --
# |    |    └─Block: 3-7                   [-1, 256, 24, 32]         1,769,984
# |    └─ModuleList: 2                     []                        --
# |    |    └─ConvTranspose2d: 3-8         [-1, 128, 48, 64]         524,416
# |    └─ModuleList: 2                     []                        --
# |    |    └─Block: 3-9                   [-1, 128, 48, 64]         442,624
# |    └─ModuleList: 2                     []                        --
# |    |    └─ConvTranspose2d: 3-10        [-1, 64, 96, 128]         131,136
# |    └─ModuleList: 2                     []                        --
# |    |    └─Block: 3-11                  [-1, 64, 96, 128]         110,720
# |    └─ModuleList: 2                     []                        --
# |    |    └─ConvTranspose2d: 3-12        [-1, 32, 192, 256]        32,800
# |    └─ModuleList: 2                     []                        --
# |    |    └─Block: 3-13                  [-1, 32, 192, 256]        27,712
# ├─Conv2d: 1-3                            [-1, 23, 192, 256]        759
# ==========================================================================================
# Total params: 9,849,783
# Trainable params: 9,849,783
# Non-trainable params: 0
# Total mult-adds (G): 6.50
# ==========================================================================================
# Input size (MB): 0.56
# Forward/backward pass size (MB): 31.12
# Params size (MB): 37.57
# Estimated Total Size (MB): 69.26
# ==========================================================================================
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ├─Encoder: 1-1                           [-1, 32, 192, 256]        --
# |    └─ModuleList: 2                     []                        --
# |    |    └─Block: 3-1                   [-1, 32, 192, 256]        10,144
# |    └─MaxPool2d: 2-1                    [-1, 32, 96, 128]         --
# |    └─ModuleList: 2                     []                        --
# |    |    └─Block: 3-2                   [-1, 64, 96, 128]         55,424
# |    └─MaxPool2d: 2-2                    [-1, 64, 48, 64]          --
# |    └─ModuleList: 2                     []                        --
# |    |    └─Block: 3-3                   [-1, 128, 48, 64]         221,440
# |    └─MaxPool2d: 2-3                    [-1, 128, 24, 32]         --
# |    └─ModuleList: 2                     []                        --
# |    |    └─Block: 3-4                   [-1, 256, 24, 32]         885,248
# |    └─MaxPool2d: 2-4                    [-1, 256, 12, 16]         --
# |    └─ModuleList: 2                     []                        --
# |    |    └─Block: 3-5                   [-1, 512, 12, 16]         3,539,968
# |    └─MaxPool2d: 2-5                    [-1, 512, 6, 8]           --
# ├─Decoder: 1-2                           [-1, 32, 192, 256]        --
# |    └─ModuleList: 2                     []                        --
# |    |    └─ConvTranspose2d: 3-6         [-1, 256, 24, 32]         2,097,408
# |    └─ModuleList: 2                     []                        --
# |    |    └─Block: 3-7                   [-1, 256, 24, 32]         1,769,984
# |    └─ModuleList: 2                     []                        --
# |    |    └─ConvTranspose2d: 3-8         [-1, 128, 48, 64]         524,416
# |    └─ModuleList: 2                     []                        --
# |    |    └─Block: 3-9                   [-1, 128, 48, 64]         442,624
# |    └─ModuleList: 2                     []                        --
# |    |    └─ConvTranspose2d: 3-10        [-1, 64, 96, 128]         131,136
# |    └─ModuleList: 2                     []                        --
# |    |    └─Block: 3-11                  [-1, 64, 96, 128]         110,720
# |    └─ModuleList: 2                     []                        --
# |    |    └─ConvTranspose2d: 3-12        [-1, 32, 192, 256]        32,800
# |    └─ModuleList: 2                     []                        --
# |    |    └─Block: 3-13                  [-1, 32, 192, 256]        27,712
# ├─Conv2d: 1-3                            [-1, 23, 192, 256]        759
# ==========================================================================================
# Total params: 9,849,783
# Trainable params: 9,849,783
# Non-trainable params: 0
# Total mult-adds (G): 6.50
# ==========================================================================================
# Input size (MB): 0.56
# Forward/backward pass size (MB): 31.12
# Params size (MB): 37.57
# Estimated Total Size (MB): 69.26
# ==========================================================================================

# %% [markdown]
# <a name='3-6'></a>
# ### 3.6 - Dataset Handling
#
# Below, define a function that allows you to display both an input image, and its ground truth: the true mask. The true mask is what your trained model output is aiming to get as close to as possible.

# %%
dataloader = DataLoader(Segmentation_Dataset(image_path, mask_path), batch_size=BATCH_SIZE, shuffle=True)

# %%
def display(display_list):
    plt.figure(figsize=(15, 15))

    title = ['Input Image', 'True Mask', 'Predicted Mask']

    for i in range(len(display_list)):
        plt.subplot(1, len(display_list), i+1)
        plt.title(title[i])
        plt.imshow(display_list[i].permute(1, 2, 0))
        plt.axis('off')
    plt.show()

# %%
# Get the first batch of data
data_iter = iter(dataloader)
first_batch = next(data_iter)

# Extract the first image and mask
first_image = first_batch['IMAGE'][0]  # First image from the batch
first_mask = first_batch['MASK'][0]    # First mask from the batch

# Display the image and mask
display([first_image, first_mask])

# %% [markdown]
# <a name='3-7'></a>
# ### 3.7 - Loss Function
#
# In semantic segmentation, you need as many masks as you have object classes. In the dataset you're using, each pixel in every mask has been assigned a single integer probability that it belongs to a certain class, from 0 to num_classes-1. The correct class is the layer with the higher probability.
#
# This is different from categorical crossentropy, where the labels should be one-hot encoded (just 0s and 1s). Here, you'll use sparse categorical crossentropy as your loss function, to perform pixel-wise multiclass prediction. Sparse categorical crossentropy is more efficient than other loss functions when you're dealing with lots of classes.

# %%
criterion = nn.CrossEntropyLoss()

# %%
optimizer = torch.optim.Adam(unet.parameters(), lr=LR, betas=(B1, B2))

# %% [markdown]
# <a name='4'></a>
# ## 4 - Train the Model

# %%
# Your original tensor
original_tensor = torch.randint(0, 23, (64, 1, 192, 256))  # Example tensor

# Convert to one-hot encoding
binary_tensor = F.one_hot(original_tensor.long().squeeze(1), num_classes=23)
binary_tensor = binary_tensor.permute(0, 3, 1, 2)  # Change from [64, 192, 256, 23] to [64, 23, 192, 256]

# %%
losses = []
for epoch in range(40):
    epoch_losses = []
    unet.train()   # set to training mode
    
    for i, batch in enumerate(dataloader):
        images = batch['IMAGE'].to(device)
        masks  = batch['MASK'].to(device)
        masks = F.one_hot(masks.long().squeeze(1), num_classes=23)
        masks = masks.permute(0, 3, 1, 2).float()
        

        # Forward pass
        outputs = unet(images)

        loss = criterion(outputs, masks)

        # Backward + optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        epoch_losses.append(loss.item())
        print(f'EPOCH#{epoch},\t Batch#{i},\t Loss:{loss.item():.4f}')
    
    losses.append(np.mean(epoch_losses))
    print('='*20)
    print(f'>>> Epoch {epoch} average loss: {losses[-1]:.4f}')
    print('='*20)
# Out:
# EPOCH#0,	 Batch#0,	 Loss:3.0594
# EPOCH#0,	 Batch#1,	 Loss:3.0456
# EPOCH#0,	 Batch#2,	 Loss:3.0371
# EPOCH#0,	 Batch#3,	 Loss:3.0276
# EPOCH#0,	 Batch#4,	 Loss:2.9910
# EPOCH#0,	 Batch#5,	 Loss:2.7627
# EPOCH#0,	 Batch#6,	 Loss:8.0583
# EPOCH#0,	 Batch#7,	 Loss:2.6135
# EPOCH#0,	 Batch#8,	 Loss:2.9035
# EPOCH#0,	 Batch#9,	 Loss:2.9345
# EPOCH#0,	 Batch#10,	 Loss:2.9456
# EPOCH#0,	 Batch#11,	 Loss:2.9410
# EPOCH#0,	 Batch#12,	 Loss:2.9428
# EPOCH#0,	 Batch#13,	 Loss:2.9348
# EPOCH#0,	 Batch#14,	 Loss:2.9263
# EPOCH#0,	 Batch#15,	 Loss:2.9115
# EPOCH#0,	 Batch#16,	 Loss:2.8950
# ====================
# >>> Epoch 0 average loss: 3.2312
# ====================
# EPOCH#1,	 Batch#0,	 Loss:2.8634
# EPOCH#1,	 Batch#1,	 Loss:2.8403
# EPOCH#1,	 Batch#2,	 Loss:2.7906
# EPOCH#1,	 Batch#3,	 Loss:2.7295
# EPOCH#1,	 Batch#4,	 Loss:2.5594
# EPOCH#1,	 Batch#5,	 Loss:2.1736
# EPOCH#1,	 Batch#6,	 Loss:2.7893
# EPOCH#1,	 Batch#7,	 Loss:1.9417
# EPOCH#1,	 Batch#8,	 Loss:2.0710
# EPOCH#1,	 Batch#9,	 Loss:2.1417
# EPOCH#1,	 Batch#10,	 Loss:2.1039
# EPOCH#1,	 Batch#11,	 Loss:2.0182
# EPOCH#1,	 Batch#12,	 Loss:1.8478
# EPOCH#1,	 Batch#13,	 Loss:1.7440
# EPOCH#1,	 Batch#14,	 Loss:1.8889
# EPOCH#1,	 Batch#15,	 Loss:1.8795
# EPOCH#1,	 Batch#16,	 Loss:1.6698
# ====================
# >>> Epoch 1 average loss: 2.2384
# ====================
# EPOCH#2,	 Batch#0,	 Loss:1.6887
# EPOCH#2,	 Batch#1,	 Loss:1.7136
# EPOCH#2,	 Batch#2,	 Loss:1.6915
# EPOCH#2,	 Batch#3,	 Loss:1.6663
# EPOCH#2,	 Batch#4,	 Loss:1.6298
# EPOCH#2,	 Batch#5,	 Loss:1.5870
# EPOCH#2,	 Batch#6,	 Loss:1.5832
# EPOCH#2,	 Batch#7,	 Loss:1.6093
# EPOCH#2,	 Batch#8,	 Loss:1.6030
# EPOCH#2,	 Batch#9,	 Loss:1.5833
# EPOCH#2,	 Batch#10,	 Loss:1.6065
# EPOCH#2,	 Batch#11,	 Loss:1.6312
# EPOCH#2,	 Batch#12,	 Loss:1.6125
# EPOCH#2,	 Batch#13,	 Loss:1.6302
# EPOCH#2,	 Batch#14,	 Loss:1.5260
# EPOCH#2,	 Batch#15,	 Loss:1.5430
# EPOCH#2,	 Batch#16,	 Loss:1.4967
# ====================
# >>> Epoch 2 average loss: 1.6119
# ====================
# EPOCH#3,	 Batch#0,	 Loss:1.5735
# EPOCH#3,	 Batch#1,	 Loss:1.5516
# EPOCH#3,	 Batch#2,	 Loss:1.5730
# EPOCH#3,	 Batch#3,	 Loss:1.5789
# EPOCH#3,	 Batch#4,	 Loss:1.5441
# EPOCH#3,	 Batch#5,	 Loss:1.5012
# EPOCH#3,	 Batch#6,	 Loss:1.5597
# EPOCH#3,	 Batch#7,	 Loss:1.5448
# EPOCH#3,	 Batch#8,	 Loss:1.5105
# EPOCH#3,	 Batch#9,	 Loss:1.5276
# EPOCH#3,	 Batch#10,	 Loss:1.4854
# EPOCH#3,	 Batch#11,	 Loss:1.5216
# EPOCH#3,	 Batch#12,	 Loss:1.4957
# EPOCH#3,	 Batch#13,	 Loss:1.4345
# EPOCH#3,	 Batch#14,	 Loss:1.3655
# EPOCH#3,	 Batch#15,	 Loss:1.4358
# EPOCH#3,	 Batch#16,	 Loss:2.2043
# ====================
# >>> Epoch 3 average loss: 1.5534
# ====================
# EPOCH#4,	 Batch#0,	 Loss:1.4395
# EPOCH#4,	 Batch#1,	 Loss:1.5418
# EPOCH#4,	 Batch#2,	 Loss:1.5279
# EPOCH#4,	 Batch#3,	 Loss:1.5409
# EPOCH#4,	 Batch#4,	 Loss:1.5371
# EPOCH#4,	 Batch#5,	 Loss:1.4747
# EPOCH#4,	 Batch#6,	 Loss:1.4909
# EPOCH#4,	 Batch#7,	 Loss:1.5271
# EPOCH#4,	 Batch#8,	 Loss:1.4840
# EPOCH#4,	 Batch#9,	 Loss:1.4885
# EPOCH#4,	 Batch#10,	 Loss:1.4851
# EPOCH#4,	 Batch#11,	 Loss:1.5083
# EPOCH#4,	 Batch#12,	 Loss:1.4974
# EPOCH#4,	 Batch#13,	 Loss:1.4860
# EPOCH#4,	 Batch#14,	 Loss:1.4508
# EPOCH#4,	 Batch#15,	 Loss:1.4958
# EPOCH#4,	 Batch#16,	 Loss:1.4312
# ====================
# >>> Epoch 4 average loss: 1.4945
# ====================
# EPOCH#5,	 Batch#0,	 Loss:1.4212
# EPOCH#5,	 Batch#1,	 Loss:1.3651
# EPOCH#5,	 Batch#2,	 Loss:1.5304
# EPOCH#5,	 Batch#3,	 Loss:1.3947
# EPOCH#5,	 Batch#4,	 Loss:1.3749
# EPOCH#5,	 Batch#5,	 Loss:1.3571
# EPOCH#5,	 Batch#6,	 Loss:1.2452
# EPOCH#5,	 Batch#7,	 Loss:1.2866
# EPOCH#5,	 Batch#8,	 Loss:1.2694
# EPOCH#5,	 Batch#9,	 Loss:1.2661
# EPOCH#5,	 Batch#10,	 Loss:1.2167
# EPOCH#5,	 Batch#11,	 Loss:1.1785
# EPOCH#5,	 Batch#12,	 Loss:1.1581
# EPOCH#5,	 Batch#13,	 Loss:2.2974
# EPOCH#5,	 Batch#14,	 Loss:1.6039
# EPOCH#5,	 Batch#15,	 Loss:1.6141
# EPOCH#5,	 Batch#16,	 Loss:1.6025
# ====================
# >>> Epoch 5 average loss: 1.4225
# ====================
# EPOCH#6,	 Batch#0,	 Loss:1.6334
# EPOCH#6,	 Batch#1,	 Loss:1.6271
# EPOCH#6,	 Batch#2,	 Loss:1.5802
# EPOCH#6,	 Batch#3,	 Loss:1.5160
# EPOCH#6,	 Batch#4,	 Loss:1.4799
# EPOCH#6,	 Batch#5,	 Loss:1.4623
# EPOCH#6,	 Batch#6,	 Loss:1.4935
# EPOCH#6,	 Batch#7,	 Loss:1.4494
# EPOCH#6,	 Batch#8,	 Loss:1.4568
# EPOCH#6,	 Batch#9,	 Loss:1.4933
# EPOCH#6,	 Batch#10,	 Loss:1.3846
# EPOCH#6,	 Batch#11,	 Loss:1.3610
# EPOCH#6,	 Batch#12,	 Loss:1.5130
# EPOCH#6,	 Batch#13,	 Loss:1.5014
# EPOCH#6,	 Batch#14,	 Loss:1.4389
# EPOCH#6,	 Batch#15,	 Loss:1.4660
# EPOCH#6,	 Batch#16,	 Loss:1.8191
# ====================
# >>> Epoch 6 average loss: 1.5103
# ====================
# EPOCH#7,	 Batch#0,	 Loss:1.4414
# EPOCH#7,	 Batch#1,	 Loss:1.4516
# EPOCH#7,	 Batch#2,	 Loss:1.4090
# EPOCH#7,	 Batch#3,	 Loss:1.3935
# EPOCH#7,	 Batch#4,	 Loss:1.4128
# EPOCH#7,	 Batch#5,	 Loss:1.3353
# EPOCH#7,	 Batch#6,	 Loss:1.4305
# EPOCH#7,	 Batch#7,	 Loss:1.2906
# EPOCH#7,	 Batch#8,	 Loss:1.3614
# EPOCH#7,	 Batch#9,	 Loss:1.4314
# EPOCH#7,	 Batch#10,	 Loss:1.5211
# EPOCH#7,	 Batch#11,	 Loss:1.4438
# EPOCH#7,	 Batch#12,	 Loss:1.4359
# EPOCH#7,	 Batch#13,	 Loss:1.4291
# EPOCH#7,	 Batch#14,	 Loss:1.3813
# EPOCH#7,	 Batch#15,	 Loss:1.3005
# EPOCH#7,	 Batch#16,	 Loss:1.4067
# ====================
# >>> Epoch 7 average loss: 1.4045
# ====================
# EPOCH#8,	 Batch#0,	 Loss:1.2757
# EPOCH#8,	 Batch#1,	 Loss:1.3005
# EPOCH#8,	 Batch#2,	 Loss:1.2468
# EPOCH#8,	 Batch#3,	 Loss:1.1900
# EPOCH#8,	 Batch#4,	 Loss:1.1640
# EPOCH#8,	 Batch#5,	 Loss:1.1597
# EPOCH#8,	 Batch#6,	 Loss:1.0948
# EPOCH#8,	 Batch#7,	 Loss:1.0338
# EPOCH#8,	 Batch#8,	 Loss:1.0497
# EPOCH#8,	 Batch#9,	 Loss:1.1000
# EPOCH#8,	 Batch#10,	 Loss:1.3075
# EPOCH#8,	 Batch#11,	 Loss:1.1795
# EPOCH#8,	 Batch#12,	 Loss:1.1255
# EPOCH#8,	 Batch#13,	 Loss:1.1804
# EPOCH#8,	 Batch#14,	 Loss:1.0922
# EPOCH#8,	 Batch#15,	 Loss:0.9553
# EPOCH#8,	 Batch#16,	 Loss:1.1744
# ====================
# >>> Epoch 8 average loss: 1.1547
# ====================
# EPOCH#9,	 Batch#0,	 Loss:1.0356
# EPOCH#9,	 Batch#1,	 Loss:1.0615
# EPOCH#9,	 Batch#2,	 Loss:1.0625
# EPOCH#9,	 Batch#3,	 Loss:0.9292
# EPOCH#9,	 Batch#4,	 Loss:0.9018
# EPOCH#9,	 Batch#5,	 Loss:1.0546
# EPOCH#9,	 Batch#6,	 Loss:0.9597
# EPOCH#9,	 Batch#7,	 Loss:0.8757
# EPOCH#9,	 Batch#8,	 Loss:0.8530
# EPOCH#9,	 Batch#9,	 Loss:0.9050
# EPOCH#9,	 Batch#10,	 Loss:0.8624
# EPOCH#9,	 Batch#11,	 Loss:0.8815
# EPOCH#9,	 Batch#12,	 Loss:0.9436
# EPOCH#9,	 Batch#13,	 Loss:0.8507
# EPOCH#9,	 Batch#14,	 Loss:0.8518
# EPOCH#9,	 Batch#15,	 Loss:0.8228
# EPOCH#9,	 Batch#16,	 Loss:0.7587
# ====================
# >>> Epoch 9 average loss: 0.9182
# ====================
# EPOCH#10,	 Batch#0,	 Loss:0.7636
# EPOCH#10,	 Batch#1,	 Loss:0.7903
# EPOCH#10,	 Batch#2,	 Loss:0.8027
# EPOCH#10,	 Batch#3,	 Loss:0.7555
# EPOCH#10,	 Batch#4,	 Loss:0.7439
# EPOCH#10,	 Batch#5,	 Loss:0.7550
# EPOCH#10,	 Batch#6,	 Loss:0.7118
# EPOCH#10,	 Batch#7,	 Loss:0.7041
# EPOCH#10,	 Batch#8,	 Loss:0.7583
# EPOCH#10,	 Batch#9,	 Loss:0.6722
# EPOCH#10,	 Batch#10,	 Loss:0.6693
# EPOCH#10,	 Batch#11,	 Loss:0.7537
# EPOCH#10,	 Batch#12,	 Loss:0.6850
# EPOCH#10,	 Batch#13,	 Loss:0.6294
# EPOCH#10,	 Batch#14,	 Loss:0.7104
# EPOCH#10,	 Batch#15,	 Loss:0.7292
# EPOCH#10,	 Batch#16,	 Loss:0.5615
# ====================
# >>> Epoch 10 average loss: 0.7174
# ====================
# EPOCH#11,	 Batch#0,	 Loss:0.6938
# EPOCH#11,	 Batch#1,	 Loss:0.6742
# EPOCH#11,	 Batch#2,	 Loss:0.7243
# EPOCH#11,	 Batch#3,	 Loss:0.6480
# EPOCH#11,	 Batch#4,	 Loss:0.6923
# EPOCH#11,	 Batch#5,	 Loss:0.6586
# EPOCH#11,	 Batch#6,	 Loss:0.6424
# EPOCH#11,	 Batch#7,	 Loss:0.6208
# EPOCH#11,	 Batch#8,	 Loss:0.5905
# EPOCH#11,	 Batch#9,	 Loss:0.5950
# EPOCH#11,	 Batch#10,	 Loss:0.6190
# EPOCH#11,	 Batch#11,	 Loss:0.6244
# EPOCH#11,	 Batch#12,	 Loss:0.5935
# EPOCH#11,	 Batch#13,	 Loss:0.5966
# EPOCH#11,	 Batch#14,	 Loss:0.6513
# EPOCH#11,	 Batch#15,	 Loss:0.6198
# EPOCH#11,	 Batch#16,	 Loss:0.6534
# ====================
# >>> Epoch 11 average loss: 0.6410
# ====================
# EPOCH#12,	 Batch#0,	 Loss:0.5856
# EPOCH#12,	 Batch#1,	 Loss:0.6072
# EPOCH#12,	 Batch#2,	 Loss:0.5714
# EPOCH#12,	 Batch#3,	 Loss:0.5532
# EPOCH#12,	 Batch#4,	 Loss:0.5865
# EPOCH#12,	 Batch#5,	 Loss:0.5932
# EPOCH#12,	 Batch#6,	 Loss:0.5744
# EPOCH#12,	 Batch#7,	 Loss:0.5846
# EPOCH#12,	 Batch#8,	 Loss:0.6183
# EPOCH#12,	 Batch#9,	 Loss:0.5943
# EPOCH#12,	 Batch#10,	 Loss:0.5350
# EPOCH#12,	 Batch#11,	 Loss:0.5572
# EPOCH#12,	 Batch#12,	 Loss:0.6058
# EPOCH#12,	 Batch#13,	 Loss:0.5708
# EPOCH#12,	 Batch#14,	 Loss:0.5545
# EPOCH#12,	 Batch#15,	 Loss:0.5651
# EPOCH#12,	 Batch#16,	 Loss:0.5161
# ====================
# >>> Epoch 12 average loss: 0.5749
# ====================
# EPOCH#13,	 Batch#0,	 Loss:0.5277
# EPOCH#13,	 Batch#1,	 Loss:0.5431
# EPOCH#13,	 Batch#2,	 Loss:0.5526
# EPOCH#13,	 Batch#3,	 Loss:0.5515
# EPOCH#13,	 Batch#4,	 Loss:0.5722
# EPOCH#13,	 Batch#5,	 Loss:0.5435
# EPOCH#13,	 Batch#6,	 Loss:0.6051
# EPOCH#13,	 Batch#7,	 Loss:0.5111
# EPOCH#13,	 Batch#8,	 Loss:0.5249
# EPOCH#13,	 Batch#9,	 Loss:0.5259
# EPOCH#13,	 Batch#10,	 Loss:0.5270
# EPOCH#13,	 Batch#11,	 Loss:0.5535
# EPOCH#13,	 Batch#12,	 Loss:0.4914
# EPOCH#13,	 Batch#13,	 Loss:0.5356
# EPOCH#13,	 Batch#14,	 Loss:0.5295
# EPOCH#13,	 Batch#15,	 Loss:0.4962
# EPOCH#13,	 Batch#16,	 Loss:0.4980
# ====================
# >>> Epoch 13 average loss: 0.5346
# ====================
# EPOCH#14,	 Batch#0,	 Loss:0.4958
# EPOCH#14,	 Batch#1,	 Loss:0.5195
# EPOCH#14,	 Batch#2,	 Loss:0.5036
# EPOCH#14,	 Batch#3,	 Loss:0.5237
# EPOCH#14,	 Batch#4,	 Loss:0.5110
# EPOCH#14,	 Batch#5,	 Loss:0.4923
# EPOCH#14,	 Batch#6,	 Loss:0.5090
# EPOCH#14,	 Batch#7,	 Loss:0.5067
# EPOCH#14,	 Batch#8,	 Loss:0.5176
# EPOCH#14,	 Batch#9,	 Loss:0.4957
# EPOCH#14,	 Batch#10,	 Loss:0.5006
# EPOCH#14,	 Batch#11,	 Loss:0.5126
# EPOCH#14,	 Batch#12,	 Loss:0.4932
# EPOCH#14,	 Batch#13,	 Loss:0.5162
# EPOCH#14,	 Batch#14,	 Loss:0.4778
# EPOCH#14,	 Batch#15,	 Loss:0.4686
# EPOCH#14,	 Batch#16,	 Loss:0.4923
# ====================
# >>> Epoch 14 average loss: 0.5021
# ====================
# EPOCH#15,	 Batch#0,	 Loss:0.4643
# EPOCH#15,	 Batch#1,	 Loss:0.4874
# EPOCH#15,	 Batch#2,	 Loss:0.4390
# EPOCH#15,	 Batch#3,	 Loss:0.5034
# EPOCH#15,	 Batch#4,	 Loss:0.4903
# EPOCH#15,	 Batch#5,	 Loss:0.4930
# EPOCH#15,	 Batch#6,	 Loss:0.4830
# EPOCH#15,	 Batch#7,	 Loss:0.4593
# EPOCH#15,	 Batch#8,	 Loss:0.4737
# EPOCH#15,	 Batch#9,	 Loss:0.4864
# EPOCH#15,	 Batch#10,	 Loss:0.4946
# EPOCH#15,	 Batch#11,	 Loss:0.4323
# EPOCH#15,	 Batch#12,	 Loss:0.4471
# EPOCH#15,	 Batch#13,	 Loss:0.4594
# EPOCH#15,	 Batch#14,	 Loss:0.5247
# EPOCH#15,	 Batch#15,	 Loss:0.4714
# EPOCH#15,	 Batch#16,	 Loss:0.4709
# ====================
# >>> Epoch 15 average loss: 0.4753
# ====================
# EPOCH#16,	 Batch#0,	 Loss:0.5007
# EPOCH#16,	 Batch#1,	 Loss:0.4432
# EPOCH#16,	 Batch#2,	 Loss:0.4499
# EPOCH#16,	 Batch#3,	 Loss:0.4766
# EPOCH#16,	 Batch#4,	 Loss:0.4547
# EPOCH#16,	 Batch#5,	 Loss:0.4118
# EPOCH#16,	 Batch#6,	 Loss:0.4388
# EPOCH#16,	 Batch#7,	 Loss:0.4582
# EPOCH#16,	 Batch#8,	 Loss:0.4546
# EPOCH#16,	 Batch#9,	 Loss:0.4519
# EPOCH#16,	 Batch#10,	 Loss:0.4350
# EPOCH#16,	 Batch#11,	 Loss:0.4234
# EPOCH#16,	 Batch#12,	 Loss:0.4558
# EPOCH#16,	 Batch#13,	 Loss:0.4250
# EPOCH#16,	 Batch#14,	 Loss:0.4174
# EPOCH#16,	 Batch#15,	 Loss:0.4230
# EPOCH#16,	 Batch#16,	 Loss:0.3549
# ====================
# >>> Epoch 16 average loss: 0.4397
# ====================
# EPOCH#17,	 Batch#0,	 Loss:0.4395
# EPOCH#17,	 Batch#1,	 Loss:0.4388
# EPOCH#17,	 Batch#2,	 Loss:0.4071
# EPOCH#17,	 Batch#3,	 Loss:0.4434
# EPOCH#17,	 Batch#4,	 Loss:0.4796
# EPOCH#17,	 Batch#5,	 Loss:0.4509
# EPOCH#17,	 Batch#6,	 Loss:0.4660
# EPOCH#17,	 Batch#7,	 Loss:0.4112
# EPOCH#17,	 Batch#8,	 Loss:0.4245
# EPOCH#17,	 Batch#9,	 Loss:0.4165
# EPOCH#17,	 Batch#10,	 Loss:0.3971
# EPOCH#17,	 Batch#11,	 Loss:0.4199
# EPOCH#17,	 Batch#12,	 Loss:0.4080
# EPOCH#17,	 Batch#13,	 Loss:0.4230
# EPOCH#17,	 Batch#14,	 Loss:0.4016
# EPOCH#17,	 Batch#15,	 Loss:0.4580
# EPOCH#17,	 Batch#16,	 Loss:0.4344
# ====================
# >>> Epoch 17 average loss: 0.4306
# ====================
# EPOCH#18,	 Batch#0,	 Loss:0.3863
# EPOCH#18,	 Batch#1,	 Loss:0.4155
# EPOCH#18,	 Batch#2,	 Loss:0.4219
# EPOCH#18,	 Batch#3,	 Loss:0.3702
# EPOCH#18,	 Batch#4,	 Loss:0.4008
# EPOCH#18,	 Batch#5,	 Loss:0.4060
# EPOCH#18,	 Batch#6,	 Loss:0.3862
# EPOCH#18,	 Batch#7,	 Loss:0.4057
# EPOCH#18,	 Batch#8,	 Loss:0.4041
# EPOCH#18,	 Batch#9,	 Loss:0.4212
# EPOCH#18,	 Batch#10,	 Loss:0.3688
# EPOCH#18,	 Batch#11,	 Loss:0.3818
# EPOCH#18,	 Batch#12,	 Loss:0.3926
# EPOCH#18,	 Batch#13,	 Loss:0.3733
# EPOCH#18,	 Batch#14,	 Loss:0.4044
# EPOCH#18,	 Batch#15,	 Loss:0.4222
# EPOCH#18,	 Batch#16,	 Loss:0.4124
# ====================
# >>> Epoch 18 average loss: 0.3984
# ====================
# EPOCH#19,	 Batch#0,	 Loss:0.3963
# EPOCH#19,	 Batch#1,	 Loss:0.4369
# EPOCH#19,	 Batch#2,	 Loss:0.3905
# EPOCH#19,	 Batch#3,	 Loss:0.3607
# EPOCH#19,	 Batch#4,	 Loss:0.3585
# EPOCH#19,	 Batch#5,	 Loss:0.3770
# EPOCH#19,	 Batch#6,	 Loss:0.3670
# EPOCH#19,	 Batch#7,	 Loss:0.3940
# EPOCH#19,	 Batch#8,	 Loss:0.3835
# EPOCH#19,	 Batch#9,	 Loss:0.3847
# EPOCH#19,	 Batch#10,	 Loss:0.3870
# EPOCH#19,	 Batch#11,	 Loss:0.3996
# EPOCH#19,	 Batch#12,	 Loss:0.3716
# EPOCH#19,	 Batch#13,	 Loss:0.3633
# EPOCH#19,	 Batch#14,	 Loss:0.3981
# EPOCH#19,	 Batch#15,	 Loss:0.4341
# EPOCH#19,	 Batch#16,	 Loss:0.3666
# ====================
# >>> Epoch 19 average loss: 0.3864
# ====================
# EPOCH#20,	 Batch#0,	 Loss:0.3441
# EPOCH#20,	 Batch#1,	 Loss:0.3525
# EPOCH#20,	 Batch#2,	 Loss:0.3702
# EPOCH#20,	 Batch#3,	 Loss:0.3733
# EPOCH#20,	 Batch#4,	 Loss:0.4008
# EPOCH#20,	 Batch#5,	 Loss:0.4114
# EPOCH#20,	 Batch#6,	 Loss:0.3818
# EPOCH#20,	 Batch#7,	 Loss:0.4071
# EPOCH#20,	 Batch#8,	 Loss:0.3825
# EPOCH#20,	 Batch#9,	 Loss:0.3729
# EPOCH#20,	 Batch#10,	 Loss:0.3493
# EPOCH#20,	 Batch#11,	 Loss:0.3989
# EPOCH#20,	 Batch#12,	 Loss:0.3509
# EPOCH#20,	 Batch#13,	 Loss:0.3415
# EPOCH#20,	 Batch#14,	 Loss:0.3604
# EPOCH#20,	 Batch#15,	 Loss:0.3620
# EPOCH#20,	 Batch#16,	 Loss:0.3802
# ====================
# >>> Epoch 20 average loss: 0.3729
# ====================
# EPOCH#21,	 Batch#0,	 Loss:0.3508
# EPOCH#21,	 Batch#1,	 Loss:0.3959
# EPOCH#21,	 Batch#2,	 Loss:0.4029
# EPOCH#21,	 Batch#3,	 Loss:0.3628
# EPOCH#21,	 Batch#4,	 Loss:0.3517
# EPOCH#21,	 Batch#5,	 Loss:0.3346
# EPOCH#21,	 Batch#6,	 Loss:0.3566
# EPOCH#21,	 Batch#7,	 Loss:0.3692
# EPOCH#21,	 Batch#8,	 Loss:0.3285
# EPOCH#21,	 Batch#9,	 Loss:0.3947
# EPOCH#21,	 Batch#10,	 Loss:0.3639
# EPOCH#21,	 Batch#11,	 Loss:0.3704
# EPOCH#21,	 Batch#12,	 Loss:0.3422
# EPOCH#21,	 Batch#13,	 Loss:0.3315
# EPOCH#21,	 Batch#14,	 Loss:0.3614
# EPOCH#21,	 Batch#15,	 Loss:0.3564
# EPOCH#21,	 Batch#16,	 Loss:0.3468
# ====================
# >>> Epoch 21 average loss: 0.3600
# ====================
# EPOCH#22,	 Batch#0,	 Loss:0.3628
# EPOCH#22,	 Batch#1,	 Loss:0.3739
# EPOCH#22,	 Batch#2,	 Loss:0.3615
# EPOCH#22,	 Batch#3,	 Loss:0.3511
# EPOCH#22,	 Batch#4,	 Loss:0.3308
# EPOCH#22,	 Batch#5,	 Loss:0.3370
# EPOCH#22,	 Batch#6,	 Loss:0.3453
# EPOCH#22,	 Batch#7,	 Loss:0.3561
# EPOCH#22,	 Batch#8,	 Loss:0.3198
# EPOCH#22,	 Batch#9,	 Loss:0.3257
# EPOCH#22,	 Batch#10,	 Loss:0.3241
# EPOCH#22,	 Batch#11,	 Loss:0.3309
# EPOCH#22,	 Batch#12,	 Loss:0.3183
# EPOCH#22,	 Batch#13,	 Loss:0.3493
# EPOCH#22,	 Batch#14,	 Loss:0.3562
# EPOCH#22,	 Batch#15,	 Loss:0.3080
# EPOCH#22,	 Batch#16,	 Loss:0.3065
# ====================
# >>> Epoch 22 average loss: 0.3387
# ====================
# EPOCH#23,	 Batch#0,	 Loss:0.3077
# EPOCH#23,	 Batch#1,	 Loss:0.3383
# EPOCH#23,	 Batch#2,	 Loss:0.3124
# EPOCH#23,	 Batch#3,	 Loss:0.3166
# EPOCH#23,	 Batch#4,	 Loss:0.3265
# EPOCH#23,	 Batch#5,	 Loss:0.3287
# EPOCH#23,	 Batch#6,	 Loss:0.2925
# EPOCH#23,	 Batch#7,	 Loss:0.3214
# EPOCH#23,	 Batch#8,	 Loss:0.3780
# EPOCH#23,	 Batch#9,	 Loss:0.3136
# EPOCH#23,	 Batch#10,	 Loss:0.3183
# EPOCH#23,	 Batch#11,	 Loss:0.3021
# EPOCH#23,	 Batch#12,	 Loss:0.3239
# EPOCH#23,	 Batch#13,	 Loss:0.3169
# EPOCH#23,	 Batch#14,	 Loss:0.3335
# EPOCH#23,	 Batch#15,	 Loss:0.3415
# EPOCH#23,	 Batch#16,	 Loss:0.3754
# ====================
# >>> Epoch 23 average loss: 0.3263
# ====================
# EPOCH#24,	 Batch#0,	 Loss:0.3970
# EPOCH#24,	 Batch#1,	 Loss:0.4536
# EPOCH#24,	 Batch#2,	 Loss:0.5202
# EPOCH#24,	 Batch#3,	 Loss:0.6516
# EPOCH#24,	 Batch#4,	 Loss:0.4411
# EPOCH#24,	 Batch#5,	 Loss:0.5161
# EPOCH#24,	 Batch#6,	 Loss:0.5763
# EPOCH#24,	 Batch#7,	 Loss:0.4759
# EPOCH#24,	 Batch#8,	 Loss:0.5451
# EPOCH#24,	 Batch#9,	 Loss:0.4214
# EPOCH#24,	 Batch#10,	 Loss:0.4546
# EPOCH#24,	 Batch#11,	 Loss:0.4799
# EPOCH#24,	 Batch#12,	 Loss:0.4668
# EPOCH#24,	 Batch#13,	 Loss:0.4344
# EPOCH#24,	 Batch#14,	 Loss:0.4229
# EPOCH#24,	 Batch#15,	 Loss:0.4588
# EPOCH#24,	 Batch#16,	 Loss:0.4635
# ====================
# >>> Epoch 24 average loss: 0.4811
# ====================
# EPOCH#25,	 Batch#0,	 Loss:0.3832
# EPOCH#25,	 Batch#1,	 Loss:0.4303
# EPOCH#25,	 Batch#2,	 Loss:0.4293
# EPOCH#25,	 Batch#3,	 Loss:0.4417
# EPOCH#25,	 Batch#4,	 Loss:0.3714
# EPOCH#25,	 Batch#5,	 Loss:0.4341
# EPOCH#25,	 Batch#6,	 Loss:0.4176
# EPOCH#25,	 Batch#7,	 Loss:0.4001
# EPOCH#25,	 Batch#8,	 Loss:0.4036
# EPOCH#25,	 Batch#9,	 Loss:0.3831
# EPOCH#25,	 Batch#10,	 Loss:0.4156
# EPOCH#25,	 Batch#11,	 Loss:0.4174
# EPOCH#25,	 Batch#12,	 Loss:0.3958
# EPOCH#25,	 Batch#13,	 Loss:0.3967
# EPOCH#25,	 Batch#14,	 Loss:0.3548
# EPOCH#25,	 Batch#15,	 Loss:0.3866
# EPOCH#25,	 Batch#16,	 Loss:0.4077
# ====================
# >>> Epoch 25 average loss: 0.4041
# ====================
# EPOCH#26,	 Batch#0,	 Loss:0.3692
# EPOCH#26,	 Batch#1,	 Loss:0.4122
# EPOCH#26,	 Batch#2,	 Loss:0.3706
# EPOCH#26,	 Batch#3,	 Loss:0.3400
# EPOCH#26,	 Batch#4,	 Loss:0.3452
# EPOCH#26,	 Batch#5,	 Loss:0.3551
# EPOCH#26,	 Batch#6,	 Loss:0.3818
# EPOCH#26,	 Batch#7,	 Loss:0.3633
# EPOCH#26,	 Batch#8,	 Loss:0.3669
# EPOCH#26,	 Batch#9,	 Loss:0.3478
# EPOCH#26,	 Batch#10,	 Loss:0.3650
# EPOCH#26,	 Batch#11,	 Loss:0.3612
# EPOCH#26,	 Batch#12,	 Loss:0.3359
# EPOCH#26,	 Batch#13,	 Loss:0.3779
# EPOCH#26,	 Batch#14,	 Loss:0.3352
# EPOCH#26,	 Batch#15,	 Loss:0.3854
# EPOCH#26,	 Batch#16,	 Loss:0.4246
# ====================
# >>> Epoch 26 average loss: 0.3669
# ====================
# EPOCH#27,	 Batch#0,	 Loss:0.3259
# EPOCH#27,	 Batch#1,	 Loss:0.3328
# EPOCH#27,	 Batch#2,	 Loss:0.3880
# EPOCH#27,	 Batch#3,	 Loss:0.3623
# EPOCH#27,	 Batch#4,	 Loss:0.3519
# EPOCH#27,	 Batch#5,	 Loss:0.3260
# EPOCH#27,	 Batch#6,	 Loss:0.3646
# EPOCH#27,	 Batch#7,	 Loss:0.3594
# EPOCH#27,	 Batch#8,	 Loss:0.3810
# EPOCH#27,	 Batch#9,	 Loss:0.3194
# EPOCH#27,	 Batch#10,	 Loss:0.3424
# EPOCH#27,	 Batch#11,	 Loss:0.3556
# EPOCH#27,	 Batch#12,	 Loss:0.3309
# EPOCH#27,	 Batch#13,	 Loss:0.3301
# EPOCH#27,	 Batch#14,	 Loss:0.3393
# EPOCH#27,	 Batch#15,	 Loss:0.3262
# EPOCH#27,	 Batch#16,	 Loss:0.3561
# ====================
# >>> Epoch 27 average loss: 0.3466
# ====================
# EPOCH#28,	 Batch#0,	 Loss:0.3332
# EPOCH#28,	 Batch#1,	 Loss:0.3099
# EPOCH#28,	 Batch#2,	 Loss:0.3352
# EPOCH#28,	 Batch#3,	 Loss:0.3332
# EPOCH#28,	 Batch#4,	 Loss:0.3249
# EPOCH#28,	 Batch#5,	 Loss:0.3511
# EPOCH#28,	 Batch#6,	 Loss:0.3257
# EPOCH#28,	 Batch#7,	 Loss:0.3733
# EPOCH#28,	 Batch#8,	 Loss:0.3249
# EPOCH#28,	 Batch#9,	 Loss:0.3223
# EPOCH#28,	 Batch#10,	 Loss:0.3184
# EPOCH#28,	 Batch#11,	 Loss:0.3016
# EPOCH#28,	 Batch#12,	 Loss:0.3265
# EPOCH#28,	 Batch#13,	 Loss:0.3521
# EPOCH#28,	 Batch#14,	 Loss:0.3226
# EPOCH#28,	 Batch#15,	 Loss:0.3039
# EPOCH#28,	 Batch#16,	 Loss:0.3165
# ====================
# >>> Epoch 28 average loss: 0.3280
# ====================
# EPOCH#29,	 Batch#0,	 Loss:0.3357
# EPOCH#29,	 Batch#1,	 Loss:0.3021
# EPOCH#29,	 Batch#2,	 Loss:0.3718
# EPOCH#29,	 Batch#3,	 Loss:0.3107
# EPOCH#29,	 Batch#4,	 Loss:0.3188
# EPOCH#29,	 Batch#5,	 Loss:0.3407
# EPOCH#29,	 Batch#6,	 Loss:0.2964
# EPOCH#29,	 Batch#7,	 Loss:0.3413
# EPOCH#29,	 Batch#8,	 Loss:0.3327
# EPOCH#29,	 Batch#9,	 Loss:0.3356
# EPOCH#29,	 Batch#10,	 Loss:0.3001
# EPOCH#29,	 Batch#11,	 Loss:0.3604
# EPOCH#29,	 Batch#12,	 Loss:0.3133
# EPOCH#29,	 Batch#13,	 Loss:0.3413
# EPOCH#29,	 Batch#14,	 Loss:0.3371
# EPOCH#29,	 Batch#15,	 Loss:0.3412
# EPOCH#29,	 Batch#16,	 Loss:0.3406
# ====================
# >>> Epoch 29 average loss: 0.3306
# ====================
# EPOCH#30,	 Batch#0,	 Loss:0.3335
# EPOCH#30,	 Batch#1,	 Loss:0.2911
# EPOCH#30,	 Batch#2,	 Loss:0.3017
# EPOCH#30,	 Batch#3,	 Loss:0.3297
# EPOCH#30,	 Batch#4,	 Loss:0.3237
# EPOCH#30,	 Batch#5,	 Loss:0.3089
# EPOCH#30,	 Batch#6,	 Loss:0.3247
# EPOCH#30,	 Batch#7,	 Loss:0.3408
# EPOCH#30,	 Batch#8,	 Loss:0.3337
# EPOCH#30,	 Batch#9,	 Loss:0.3299
# EPOCH#30,	 Batch#10,	 Loss:0.3055
# EPOCH#30,	 Batch#11,	 Loss:0.3012
# EPOCH#30,	 Batch#12,	 Loss:0.2917
# EPOCH#30,	 Batch#13,	 Loss:0.3065
# EPOCH#30,	 Batch#14,	 Loss:0.3209
# EPOCH#30,	 Batch#15,	 Loss:0.2936
# EPOCH#30,	 Batch#16,	 Loss:0.2721
# ====================
# >>> Epoch 30 average loss: 0.3123
# ====================
# EPOCH#31,	 Batch#0,	 Loss:0.3240
# EPOCH#31,	 Batch#1,	 Loss:0.3183
# EPOCH#31,	 Batch#2,	 Loss:0.2952
# EPOCH#31,	 Batch#3,	 Loss:0.2934
# EPOCH#31,	 Batch#4,	 Loss:0.2981
# EPOCH#31,	 Batch#5,	 Loss:0.3034
# EPOCH#31,	 Batch#6,	 Loss:0.3158
# EPOCH#31,	 Batch#7,	 Loss:0.2903
# EPOCH#31,	 Batch#8,	 Loss:0.2839
# EPOCH#31,	 Batch#9,	 Loss:0.2823
# EPOCH#31,	 Batch#10,	 Loss:0.2789
# EPOCH#31,	 Batch#11,	 Loss:0.2817
# EPOCH#31,	 Batch#12,	 Loss:0.2827
# EPOCH#31,	 Batch#13,	 Loss:0.3010
# EPOCH#31,	 Batch#14,	 Loss:0.2767
# EPOCH#31,	 Batch#15,	 Loss:0.2882
# EPOCH#31,	 Batch#16,	 Loss:0.2911
# ====================
# >>> Epoch 31 average loss: 0.2944
# ====================
# EPOCH#32,	 Batch#0,	 Loss:0.2974
# EPOCH#32,	 Batch#1,	 Loss:0.3314
# EPOCH#32,	 Batch#2,	 Loss:0.2959
# EPOCH#32,	 Batch#3,	 Loss:0.2911
# EPOCH#32,	 Batch#4,	 Loss:0.2966
# EPOCH#32,	 Batch#5,	 Loss:0.2991
# EPOCH#32,	 Batch#6,	 Loss:0.3030
# EPOCH#32,	 Batch#7,	 Loss:0.2956
# EPOCH#32,	 Batch#8,	 Loss:0.3069
# EPOCH#32,	 Batch#9,	 Loss:0.3044
# EPOCH#32,	 Batch#10,	 Loss:0.3183
# EPOCH#32,	 Batch#11,	 Loss:0.3227
# EPOCH#32,	 Batch#12,	 Loss:0.2887
# EPOCH#32,	 Batch#13,	 Loss:0.2738
# EPOCH#32,	 Batch#14,	 Loss:0.2814
# EPOCH#32,	 Batch#15,	 Loss:0.3448
# EPOCH#32,	 Batch#16,	 Loss:0.2805
# ====================
# >>> Epoch 32 average loss: 0.3019
# ====================
# EPOCH#33,	 Batch#0,	 Loss:0.2741
# EPOCH#33,	 Batch#1,	 Loss:0.2898
# EPOCH#33,	 Batch#2,	 Loss:0.2741
# EPOCH#33,	 Batch#3,	 Loss:0.2696
# EPOCH#33,	 Batch#4,	 Loss:0.2763
# EPOCH#33,	 Batch#5,	 Loss:0.3068
# EPOCH#33,	 Batch#6,	 Loss:0.3235
# EPOCH#33,	 Batch#7,	 Loss:0.2718
# EPOCH#33,	 Batch#8,	 Loss:0.2913
# EPOCH#33,	 Batch#9,	 Loss:0.2701
# EPOCH#33,	 Batch#10,	 Loss:0.2738
# EPOCH#33,	 Batch#11,	 Loss:0.2781
# EPOCH#33,	 Batch#12,	 Loss:0.3088
# EPOCH#33,	 Batch#13,	 Loss:0.2850
# EPOCH#33,	 Batch#14,	 Loss:0.2764
# EPOCH#33,	 Batch#15,	 Loss:0.2689
# EPOCH#33,	 Batch#16,	 Loss:0.3084
# ====================
# >>> Epoch 33 average loss: 0.2851
# ====================
# EPOCH#34,	 Batch#0,	 Loss:0.2744
# EPOCH#34,	 Batch#1,	 Loss:0.2615
# EPOCH#34,	 Batch#2,	 Loss:0.2692
# EPOCH#34,	 Batch#3,	 Loss:0.2737
# EPOCH#34,	 Batch#4,	 Loss:0.3044
# EPOCH#34,	 Batch#5,	 Loss:0.2725
# EPOCH#34,	 Batch#6,	 Loss:0.3016
# EPOCH#34,	 Batch#7,	 Loss:0.2520
# EPOCH#34,	 Batch#8,	 Loss:0.2983
# EPOCH#34,	 Batch#9,	 Loss:0.2844
# EPOCH#34,	 Batch#10,	 Loss:0.2791
# EPOCH#34,	 Batch#11,	 Loss:0.2641
# EPOCH#34,	 Batch#12,	 Loss:0.2421
# EPOCH#34,	 Batch#13,	 Loss:0.2660
# EPOCH#34,	 Batch#14,	 Loss:0.2995
# EPOCH#34,	 Batch#15,	 Loss:0.2506
# EPOCH#34,	 Batch#16,	 Loss:0.2608
# ====================
# >>> Epoch 34 average loss: 0.2738
# ====================
# EPOCH#35,	 Batch#0,	 Loss:0.2602
# EPOCH#35,	 Batch#1,	 Loss:0.2597
# EPOCH#35,	 Batch#2,	 Loss:0.2562
# EPOCH#35,	 Batch#3,	 Loss:0.2641
# EPOCH#35,	 Batch#4,	 Loss:0.2238
# EPOCH#35,	 Batch#5,	 Loss:0.2665
# EPOCH#35,	 Batch#6,	 Loss:0.3478
# EPOCH#35,	 Batch#7,	 Loss:0.3090
# EPOCH#35,	 Batch#8,	 Loss:0.2926
# EPOCH#35,	 Batch#9,	 Loss:0.3690
# EPOCH#35,	 Batch#10,	 Loss:0.3565
# EPOCH#35,	 Batch#11,	 Loss:0.3526
# EPOCH#35,	 Batch#12,	 Loss:0.3062
# EPOCH#35,	 Batch#13,	 Loss:0.3457
# EPOCH#35,	 Batch#14,	 Loss:0.3105
# EPOCH#35,	 Batch#15,	 Loss:0.2885
# EPOCH#35,	 Batch#16,	 Loss:0.3147
# ====================
# >>> Epoch 35 average loss: 0.3014
# ====================
# EPOCH#36,	 Batch#0,	 Loss:0.2997
# EPOCH#36,	 Batch#1,	 Loss:0.3035
# EPOCH#36,	 Batch#2,	 Loss:0.2655
# EPOCH#36,	 Batch#3,	 Loss:0.2679
# EPOCH#36,	 Batch#4,	 Loss:0.2932
# EPOCH#36,	 Batch#5,	 Loss:0.3021
# EPOCH#36,	 Batch#6,	 Loss:0.2497
# EPOCH#36,	 Batch#7,	 Loss:0.2827
# EPOCH#36,	 Batch#8,	 Loss:0.2737
# EPOCH#36,	 Batch#9,	 Loss:0.2705
# EPOCH#36,	 Batch#10,	 Loss:0.2744
# EPOCH#36,	 Batch#11,	 Loss:0.2601
# EPOCH#36,	 Batch#12,	 Loss:0.2984
# EPOCH#36,	 Batch#13,	 Loss:0.3004
# EPOCH#36,	 Batch#14,	 Loss:0.2543
# EPOCH#36,	 Batch#15,	 Loss:0.2914
# EPOCH#36,	 Batch#16,	 Loss:0.2627
# ====================
# >>> Epoch 36 average loss: 0.2794
# ====================
# EPOCH#37,	 Batch#0,	 Loss:0.2827
# EPOCH#37,	 Batch#1,	 Loss:0.2570
# EPOCH#37,	 Batch#2,	 Loss:0.2585
# EPOCH#37,	 Batch#3,	 Loss:0.2621
# EPOCH#37,	 Batch#4,	 Loss:0.2448
# EPOCH#37,	 Batch#5,	 Loss:0.2529
# EPOCH#37,	 Batch#6,	 Loss:0.2610
# EPOCH#37,	 Batch#7,	 Loss:0.2380
# EPOCH#37,	 Batch#8,	 Loss:0.2739
# EPOCH#37,	 Batch#9,	 Loss:0.2682
# EPOCH#37,	 Batch#10,	 Loss:0.2450
# EPOCH#37,	 Batch#11,	 Loss:0.2414
# EPOCH#37,	 Batch#12,	 Loss:0.2330
# EPOCH#37,	 Batch#13,	 Loss:0.2369
# EPOCH#37,	 Batch#14,	 Loss:0.2409
# EPOCH#37,	 Batch#15,	 Loss:0.2553
# EPOCH#37,	 Batch#16,	 Loss:0.2638
# ====================
# >>> Epoch 37 average loss: 0.2538
# ====================
# EPOCH#38,	 Batch#0,	 Loss:0.2413
# EPOCH#38,	 Batch#1,	 Loss:0.2628
# EPOCH#38,	 Batch#2,	 Loss:0.2297
# EPOCH#38,	 Batch#3,	 Loss:0.2531
# EPOCH#38,	 Batch#4,	 Loss:0.2426
# EPOCH#38,	 Batch#5,	 Loss:0.2345
# EPOCH#38,	 Batch#6,	 Loss:0.2240
# EPOCH#38,	 Batch#7,	 Loss:0.2886
# EPOCH#38,	 Batch#8,	 Loss:0.2646
# EPOCH#38,	 Batch#9,	 Loss:0.2657
# EPOCH#38,	 Batch#10,	 Loss:0.2334
# EPOCH#38,	 Batch#11,	 Loss:0.2593
# EPOCH#38,	 Batch#12,	 Loss:0.2286
# EPOCH#38,	 Batch#13,	 Loss:0.2141
# EPOCH#38,	 Batch#14,	 Loss:0.2460
# EPOCH#38,	 Batch#15,	 Loss:0.2110
# EPOCH#38,	 Batch#16,	 Loss:0.2607
# ====================
# >>> Epoch 38 average loss: 0.2447
# ====================
# EPOCH#39,	 Batch#0,	 Loss:0.2401
# EPOCH#39,	 Batch#1,	 Loss:0.2659
# EPOCH#39,	 Batch#2,	 Loss:0.2550
# EPOCH#39,	 Batch#3,	 Loss:0.2551
# EPOCH#39,	 Batch#4,	 Loss:0.2647
# EPOCH#39,	 Batch#5,	 Loss:0.2204
# EPOCH#39,	 Batch#6,	 Loss:0.2606
# EPOCH#39,	 Batch#7,	 Loss:0.2443
# EPOCH#39,	 Batch#8,	 Loss:0.2336
# EPOCH#39,	 Batch#9,	 Loss:0.2261
# EPOCH#39,	 Batch#10,	 Loss:0.2181
# EPOCH#39,	 Batch#11,	 Loss:0.2169
# EPOCH#39,	 Batch#12,	 Loss:0.2399
# EPOCH#39,	 Batch#13,	 Loss:0.2415
# EPOCH#39,	 Batch#14,	 Loss:0.2376
# EPOCH#39,	 Batch#15,	 Loss:0.2367
# EPOCH#39,	 Batch#16,	 Loss:0.2368
# ====================
# >>> Epoch 39 average loss: 0.2408
# ====================

# %% [markdown]
# <a name='4-1'></a>
# ### 4.1 - Create Predicted Masks
#
# Now, define a function that uses `torch.argmax` in the axis of the number of classes to return the index with the largest value and merge the prediction into a single image:

# %%
def create_mask(pred_mask):
    """
    Convert model output probabilities to class indices mask
    
    Args:
        pred_mask: torch.Tensor of shape (N, 23, H, W) - model output logits
    
    Returns:
        pred_mask: torch.Tensor of shape (N, 1, H, W) - class indices from 0 to 22
    """
    
    # Use torch.argmax along the class dimension (dim=1) to get the predicted class for each pixel
    pred_mask = torch.argmax(pred_mask, dim=1)  # Shape: (N, H, W)
    
    # Add channel dimension to get (N, 1, H, W)
    pred_mask = pred_mask.unsqueeze(1)  # Shape: (N, 1, H, W)
    
    return pred_mask

# %% [markdown]
# <a name='4-2'></a>
# ### 4.2 - Plot Model Accuracy
#
# Let's see how your model did!

# %%
plt.plot(np.arange(len(losses)), losses)

# %% [markdown]
# <a name='4-3'></a>
# ### 4.3 - Show Predictions
#
# Next, check your predicted masks against the true mask and the original input image:

# %%
def show_predictions(dataloader, device, num=1):
    """
    Displays the first image of each of the num batches
    """
    unet.eval()  # Set model to evaluation mode
    
    with torch.no_grad():  # Disable gradient computation
        for i, batch in enumerate(dataloader):
            IMG = batch["IMAGE"].to(device)
            MASK = batch["MASK"].to(device)

            pred_mask = unet(IMG)
            display([IMG[0].cpu(), MASK[0].cpu(), create_mask(pred_mask)[0].cpu()])

            if i >= num:
                break

# %%
show_predictions(dataloader, device, 6)

# %% [markdown]
# <font color='blue'>
#
# **What you should remember**:
#
# * Semantic image segmentation predicts a label for every single pixel in an image
# * U-Net uses an equal number of convolutional blocks and transposed convolutions for downsampling and upsampling
# * Skip connections are used to prevent border pixel information loss and overfitting in U-Net
